# %%
import xml.etree.ElementTree as ET

# %%
for event, elem in ET.iterparse("Desktop/hmdb_metabolites.xml"):
    if elem.tag == '{http://www.hmdb.ca}accession':
        print(elem.text)
        elem.clear()
    if elem.tag == '{http://www.hmdb.ca}secondary_accessions':
        root = tree.
# Out:
# HMDB0000001
# HMDB00001
# HMDB0004935
# HMDB0006703
# HMDB0006704
# HMDB04935
# HMDB06703
# HMDB06704
#
#
# HMDB0000002
# HMDB00002
# HMDB0060172
# HMDB60172
#
#
# HMDB0000005
# HMDB00005
# HMDB0006544
# HMDB06544
#
#
# HMDB0000008
# HMDB00008
#
#
# HMDB0000010
# HMDB00010
# HMDB0004990
# HMDB0004991
# HMDB04990
# HMDB04991
#
#
# HMDB0000011
# HMDB0000357
# HMDB00011
# HMDB00357
#
#
# HMDB0000012
# HMDB00012
#
#
# HMDB0000014
# HMDB00014
#
#
# HMDB0000015
# HMDB00015
#
#
# HMDB0000016
# HMDB00016
#
#
# HMDB0000017
# HMDB00017
#
#
# HMDB0000019
# HMDB00019
# HMDB0004260
# HMDB04260
#
#
# HMDB0000020
# HMDB00020
#
#
# HMDB0000021
# HMDB00021
#
#
# HMDB0000022
# HMDB00022
# HMDB0006022
# HMDB06022
#
#
# HMDB0000023
# HMDB0000435
# HMDB00023
# HMDB00435
# HMDB0062640
# HMDB0126088
# HMDB62640
#
#
# HMDB0000024
# HMDB00024
#
#
# HMDB0000026
# HMDB00026
# HMDB0062812
# HMDB62812
#
#
# HMDB0000027
# HMDB0000787
# HMDB0002154
# HMDB00027
# HMDB0059658
# HMDB00787
# HMDB02154
# HMDB59658
#
#
# ...

# %%
d = {}

# %%
i = 0
d = {}
for event, elem in ET.iterparse("Desktop/hmdb_metabolites.xml", events=("start", "end")):
    if elem.tag == '{http://www.hmdb.ca}metabolite':
        for secelem in list(elem):
            if secelem.tag == '{http://www.hmdb.ca}accession':
                #print(secelem.text)
                metab_key = secelem.text
                d[metab_key] = []
            if secelem.tag == '{http://www.hmdb.ca}secondary_accessions':
                for terelem in list(secelem):
                    #print(terelem.text)
                    d[metab_key].append(terelem.text)
        elem.clear()
        i = i+1
        if i > 10000000000000:
            break

# %%
d
# Out:
# {'HMDB0000001': ['HMDB00001',
#   'HMDB0004935',
#   'HMDB0006703',
#   'HMDB0006704',
#   'HMDB04935',
#   'HMDB06703',
#   'HMDB06704'],
#  'HMDB0000002': ['HMDB00002', 'HMDB0060172', 'HMDB60172'],
#  'HMDB0000005': ['HMDB00005', 'HMDB0006544', 'HMDB06544'],
#  'HMDB0000008': ['HMDB00008'],
#  'HMDB0000010': ['HMDB00010',
#   'HMDB0004990',
#   'HMDB0004991',
#   'HMDB04990',
#   'HMDB04991'],
#  'HMDB0000011': ['HMDB0000357', 'HMDB00011', 'HMDB00357'],
#  'HMDB0000012': ['HMDB00012'],
#  'HMDB0000014': ['HMDB00014'],
#  'HMDB0000015': ['HMDB00015'],
#  'HMDB0000016': ['HMDB00016'],
#  'HMDB0000017': ['HMDB00017'],
#  'HMDB0000019': ['HMDB00019', 'HMDB0004260', 'HMDB04260'],
#  'HMDB0000020': ['HMDB00020'],
#  'HMDB0000021': ['HMDB00021'],
#  'HMDB0000022': ['HMDB00022', 'HMDB0006022', 'HMDB06022'],
#  'HMDB0000023': ['HMDB0000435',
#   'HMDB00023',
#   'HMDB00435',
#   'HMDB0062640',
#   'HMDB0126088',
#   'HMDB62640'],
#  'HMDB0000024': ['HMDB00024'],
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(d, orient='index')

# %%
df
# Out:
#                     0            1            2            3          4   \
# HMDB0000001  HMDB00001  HMDB0004935  HMDB0006703  HMDB0006704  HMDB04935
# HMDB0000002  HMDB00002  HMDB0060172    HMDB60172         None       None
# HMDB0000005  HMDB00005  HMDB0006544    HMDB06544         None       None
# HMDB0000008  HMDB00008         None         None         None       None
# HMDB0000010  HMDB00010  HMDB0004990  HMDB0004991    HMDB04990  HMDB04991
# ...                ...          ...          ...          ...        ...
# HMDB0304947       None         None         None         None       None
# HMDB0304950       None         None         None         None       None
# HMDB0304951       None         None         None         None       None
# HMDB0304953       None         None         None         None       None
# HMDB0304954       None         None         None         None       None
#
#                     5          6     7     8     9   ...    15    16    17  \
# ...

# %%
df.to_csv("Dropbox/recon3D_BIGG/support/HMDB_full_mapping.csv")
